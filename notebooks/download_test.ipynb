# %%
from download_data import get_year_links

year_links = get_year_links()
print("Extracted Year Links:", year_links)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from download_data import get_year_links
#       3 year_links = get_year_links()
#       4 print("Extracted Year Links:", year_links)
#
# ModuleNotFoundError: No module named 'download_data'

# %%
# Out:
# C:\Users\Chris\CodingBootcamp\Homework\bridge_Element_examiner

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(response.text[:2000])  # Print first 2000 characters of the page
#
# NameError: name 'response' is not defined

# %%
from download_data import get_year_links

year_links = get_year_links()
print("Extracted Year Links:", year_links)
# Out:
# HTTP Status Code: 200
# Page Content Sample:
#  <!DOCTYPE html>
# <html lang="en">
#
#
# <head>
# <!--[if IE 9]> <html class="ie9"> <![endif]-->
#
#
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#
# <meta name="msvalidate.01" content="44D41FB1AC5699252BC80EEF9FDD7F12" />
#
# <title>Federal Highway Administration</title>
# <link href="/css/fhwa2/screen.css" media="screen" rel="stylesheet" type="text/css" /> <!-- general stylesheet -->
# <link href="/css/fhwa2/dropdown.css" rel="stylesheet" type="text/css" /> <!-- submenu dropdown -->
# <link href="/css/fhwa2/print.css" media="print" rel="stylesheet" type="text/css" /> <!-- print stylesheet -->
#
#
# <link rel="icon" href="/images/fhwa2/icon/favicon.ico" type="image/x-icon" /> <!-- favicon -->
# <link rel="apple-touch-icon" href="/images/fhwa2/icon/appledotseal.png" />
# ...

# %%
print(response.text[:2000])  # Print first 2000 characters of the page
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(response.text[:2000])  # Print first 2000 characters of the page
#
# NameError: name 'response' is not defined
