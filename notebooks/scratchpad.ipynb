# %% [raw]
# Scratchpad Notebook

# %%
import sys
import os

# Get the absolute path of the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
src_path = os.path.join(project_root, "src")

# Add src/ to the Python path
sys.path.append(src_path)

# Verify it's correctly added
print("Updated sys.path:", sys.path)
# Out:
# Updated sys.path: ['C:\\Users\\Chris\\.conda\\envs\\myenv\\python311.zip', 'C:\\Users\\Chris\\.conda\\envs\\myenv\\DLLs', 'C:\\Users\\Chris\\.conda\\envs\\myenv\\Lib', 'C:\\Users\\Chris\\.conda\\envs\\myenv', '', 'C:\\Users\\Chris\\AppData\\Roaming\\Python\\Python311\\site-packages', 'C:\\Users\\Chris\\.conda\\envs\\myenv\\Lib\\site-packages', 'C:\\Users\\Chris\\.conda\\envs\\myenv\\Lib\\site-packages\\win32', 'C:\\Users\\Chris\\.conda\\envs\\myenv\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\Chris\\.conda\\envs\\myenv\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\Chris\\CodingBootcamp\\Homework\\bridge_Element_examiner\\src']

# %%
import os
print(os.listdir('../src'))
# Out:
# ['data', 'download_data.py', 'parse_xml.py', '__init__.py', '__pycache__']
