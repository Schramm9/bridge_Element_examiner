# %%
from src.data.download_data import (
    get_most_recent_year_and_states,
    download_state_files_for_year,
    download_ascii_files_for_years
)

# Step 1: Get latest year and available states
latest_year, state_links = get_most_recent_year_and_states()
print(f"Latest Year: {latest_year}")
print("Available States:", list(state_links.keys()))

# Step 2: Simulate user selection
selected_state = "New York"  # Replace this with dropdown in future interface

# Step 3: Download selected state data from element.cfm
filepath = download_state_files_for_year(selected_state, state_links, "element")

# Step 4: Download ASCII data for matching years
download_ascii_files_for_years([latest_year])
from src.data.download_data import (
    get_most_recent_year_and_states,
    download_state_files_for_year,
    download_ascii_files_for_years
)

# Step 1: Get latest year and available states
latest_year, state_links = get_most_recent_year_and_states()
print(f"Latest Year: {latest_year}")
print("Available States:", list(state_links.keys()))

# Step 2: Simulate user selection
selected_state = "California"  # Replace this with dropdown in future interface

# Step 3: Download selected state data from element.cfm
filepath = download_state_files_for_year(selected_state, state_links, "element")

# Step 4: Download ASCII data for matching years
download_ascii_files_for_years([latest_year])
